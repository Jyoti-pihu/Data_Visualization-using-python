# %% [markdown]
# # Data Analysis and visualization Assignment

# %% [markdown]
# This assignment involves performing data analysis and visualization on two datasets using python programming language. The datasets used are:

# %% [markdown]
# Airbnb dataset

# %% [raw]
# HR Dataset.

# %% [markdown]
# # Creating visualization for airbnb dataset.

# %%
# Importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as pt

# %%
import datetime as dt

# %%
import missingno as msno

# %%
## Read the datasets
airbnb= pd.read_csv("Airbnb Dataset 19.csv")

# %%
#prints the header of a DataFrame.
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# prints datatypes of all columns in a DataFrame
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# provides a bird's eye view of column data types and missing values in a DataFrame
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              249 non-null    int64
#  1   name                            249 non-null    object
#  2   host_id                         249 non-null    int64
#  3   host_name                       249 non-null    object
#  4   neighbourhood_group             249 non-null    object
#  5   neighbourhood                   249 non-null    object
#  6   latitude                        249 non-null    float64
#  7   longitude                       249 non-null    float64
#  8   room_type                       249 non-null    object
#  9   price                           249 non-null    int64
#  10  minimum_nights                  249 non-null    int64
#  11  number_of_reviews               249 non-null    int64
# ...

# %% [markdown]
# The describe() function is a method of pandas dataframes in Python that is used to generate descriptive statistics of the dataframe.
#
# When called on a dataframe, the describe() function returns a summary of the central tendency, dispersion and shape of the distribution of a dataset.

# %%
# Returns a distribution of numeric columns in your DataFrame
airbnb.describe()
# Out:
#                  id       host_id    latitude   longitude       price  \
# count    249.000000  2.490000e+02  249.000000  249.000000  249.000000
# mean   31376.771084  1.499884e+05   40.730257  -73.964044  143.971888
# std    18101.018309  4.010393e+05    0.049660    0.029685   91.442975
# min     2539.000000  2.787000e+03   40.631880  -74.080880   35.000000
# 25%    15711.000000  5.014800e+04   40.688430  -73.984980   85.000000
# 50%    28321.000000  9.779700e+04   40.721620  -73.964280  125.000000
# 75%    46911.000000  1.936370e+05   40.761930  -73.948220  175.000000
# max    62430.000000  6.197784e+06   40.867540  -73.765970  800.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count      249.000000         249.000000         242.000000
# mean         8.718876         103.445783           1.091653
# std         20.398680         100.337887           1.000168
# min          1.000000           0.000000           0.010000
# ...

# %% [markdown]
#  #In the data information there are values are missing in some columns
#
#
#  #Break down the number of missing values per column in the DataFrame
#
#
#  #allows us to break down the number of missing values per column in our DataFrame

# %%
airbnb.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       7
# reviews_per_month                 7
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# print the number of Rows and columns in the dataset.
print('Number of Rows and columns in the dataset :', airbnb.shape)
# Out:
# Number of Rows and columns in the dataset : (249, 16)

# %%
## ID is a unique value in the dataset from where we can identify the number of duplicate data present in the dataset
## Find duplicates values in the 'id' column
duplicates = airbnb.duplicated(subset= 'id', keep= False)
airbnb[duplicates].sort_values('id')
## There are no duplicate value in the id column.
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
# Remove all duplicated data
airbnb.duplicated().sum()
# Out:
# 0

# %%
airbnb.nunique()
# Out:
# id                                249
# name                              249
# host_id                           218
# host_name                         204
# neighbourhood_group                 5
# neighbourhood                      55
# latitude                          249
# longitude                         245
# room_type                           3
# price                              86
# minimum_nights                     23
# number_of_reviews                 154
# last_review                       129
# reviews_per_month                 160
# calculated_host_listings_count      6
# availability_365                  152
# dtype: int64

# %%
airbnb["last_review"].isnull().sum()
# Out:
# 7

# %%
airbnb['last_review'].fillna('_', inplace=True)

# %%
airbnb['last_review'].isnull().sum()
# Out:
# 0

# %%
airbnb['reviews_per_month'].isnull().sum()
# Out:
# 7

# %%
airbnb['reviews_per_month'].fillna('_', inplace=True)

# %%
airbnb['reviews_per_month'].isnull().sum()
# Out:
# 0

# %% [markdown]
# The .describe() function is used to generate descriptive statistics of the DataFrame. When used with the .isna() function, it generates descriptive statistics only for the columns with missing values, which can help to better understand the distribution and nature of missing values in the dataset.

# %%
## Check again for null values in columns
airbnb.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# The drop() function is a method of pandas dataframes in Python that is used to remove rows or columns from the dataframe.
#
#
# When called on a dataframe, the drop() function returns a new dataframe that has had the specified rows or columns removed.

# %%
## Drop columns which are not relevent
airbnb.drop(['id','host_id','last_review'], axis= 1, inplace= True)

# %% [markdown]
# Tha value_counts() function in python is used to return a pandas series containing counts of unique values in a given data frame column.

# %%
## Values of different neighbourhood_group we have.
airbnb['neighbourhood_group'].value_counts()
# Out:
# Manhattan        124
# Brooklyn         111
# Queens            11
# Bronx              2
# Staten Island      1
# Name: neighbourhood_group, dtype: int64

# %%
airbnb['neighbourhood_group'].value_counts().index
# Out:
# Index(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'], dtype='object')

# %% [markdown]
# # Visualizing the Data

# %% [markdown]
# Pie chart visualization of the 'neighbourhood_group'
#
# The pie chart visualization of the neighbourhood_group column provides an overview of the distribution of listings among different neighbourhood groups in the dataset. The chart is useful in showing the proportion of each neighbourhood group in the dataset and can help in identifying the most and least represented groups.

# %%
airbnb.to_csv('airbnb_clean.csv')

# %%
## Pie-chart of different neighbourhood groups.
labels_ngroup = airbnb['neighbourhood_group'].value_counts().index
sizes_ngroup = airbnb['neighbourhood_group'].value_counts()
explode = [0.1, 0.1, 0.1, 0.5, 0.9]

plt.figure(figsize = (7, 7))
plt.pie(sizes_ngroup, labels = labels_ngroup, explode = ([0, 0.01, 0.1, 0.5, 0.9]), shadow = True)
plt.title('AirBnb in Neighbourhood Group', fontsize= 20)
plt.show()

# %%
corr = airbnb.corr()
corr
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2488\2876876252.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = airbnb.corr()
#                                 latitude  longitude     price  minimum_nights  \
# latitude                        1.000000   0.163688 -0.076422        0.000398
# longitude                       0.163688   1.000000 -0.235756       -0.042712
# price                          -0.076422  -0.235756  1.000000        0.051217
# minimum_nights                  0.000398  -0.042712  0.051217        1.000000
# number_of_reviews               0.000859  -0.074639 -0.206950       -0.128352
# calculated_host_listings_count -0.089450   0.176826 -0.131999       -0.111958
# availability_365                0.066022   0.067338  0.010685       -0.069384
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(corr , annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Bar chart visualization of the 'neighbourhood_group'
#
# A barplot of the number of neighbourhood groups present in the neighbourhood_group column provides a clear visualization of the distribution of neighbourhood groups in the dataset.

# %%
## Barplot of different neighbourhood_group
plt.figure(figsize = (15, 5))
sns.barplot(x=labels_ngroup, y=sizes_ngroup, data=airbnb)

# Set the axis labels and title
plt.xlabel('Neighbourhood Group', fontsize= 16)
plt.ylabel('Total Count', fontsize= 16)
plt.title('Number of Neighbourhood Group', fontsize= 25)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.show()

# %% [markdown]
# Bar chart visualization of the top 10 neighborhoods present in the dataset

# %%
## Values of different top 10 neighbourhood.
airbnb['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          26
# Harlem                22
# East Village          20
# Bedford-Stuyvesant    17
# Hell's Kitchen        12
# Clinton Hill           9
# Upper West Side        9
# Fort Greene            8
# West Village           8
# Lower East Side        8
# Name: neighbourhood, dtype: int64

# %%
## Barplot of different neighbourhood
labels_nh = airbnb['neighbourhood'].value_counts().head(10).index
sizes_nh = airbnb['neighbourhood'].value_counts().head(10)

plt.figure(figsize = (22, 8))
sns.barplot(x=labels_nh, y=sizes_nh, data=airbnb)

# Set the axis labels and title
plt.xlabel('Neighbourhood', fontsize= 16)
plt.ylabel('Total Count', fontsize= 16)
plt.title('Number of Top 10 Host Names', fontsize= 25)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.show()

# %%
minimum_nights_ax = airbnb.groupby('minimum_nights')['price'].mean()
minimum_nights_ax
# Out:
# minimum_nights
# 1      137.437500
# 2      136.968254
# 3      141.875000
# 4      161.956522
# 5      168.428571
# 6      148.750000
# 7      145.600000
# 8      197.000000
# 9      230.000000
# 10     115.000000
# 14     132.500000
# 15      95.000000
# 26     162.500000
# 28     125.000000
# 29     171.666667
# 30     139.400000
# 31     110.000000
# 45     142.500000
# 50     130.000000
# 60      35.000000
# 90     122.500000
# 180    375.000000
# 200    110.000000
# Name: price, dtype: float64

# %%
airbnb.minimum_nights.plot.hist()
plt.show()

# %%
airbnb['price'] = airbnb['price'].astype('float')
airbnb['price'].mean()
# Out:
# 143.9718875502008

# %%
sns.distplot(airbnb['price'], bins =20)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2488\1256495632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['price'], bins =20)

# %%
airbnb['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
sns.distplot(airbnb['number_of_reviews'], bins=10)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2488\722894369.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['number_of_reviews'], bins=10)

# %% [markdown]
# Dealing with missing data
#
# The msno.bar function is part of the missingno library in Python, and it is used to create a bar chart or matrix to visualize the missing values in a dataset. The bar chart shows the number of non-missing values for each column in the dataset, while the bar chart shows the locations of missing values in the dataset.
# This function is useful for identifying patterns and relationships between missing values in a dataset, and can help in determining the best way to handle them, such as imputing missing values or dropping columns or rows with too many missing values.

# %%
msno.bar(airbnb)
plt.show()

# %%
airbnb['room_type'].value_counts()
# Out:
# Entire home/apt    134
# Private room       113
# Shared room          2
# Name: room_type, dtype: int64

# %%
sns.boxplot(x = 'room_type', y = 'price', data = airbnb)
plt.ylim(0,400)
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.show()

# %%
## Lets visualize the chart for room_types
labels_room = airbnb['room_type'].value_counts().index
sizes_room = airbnb['room_type'].value_counts()
explode = [0, 0, 0.5]
colors = ['#0B2447','#E49393','#539165']

plt.figure(figsize = (7, 7))
plt.pie(sizes_room, labels = labels_room,colors= colors, explode= explode, autopct= '%1.1f%%', startangle= 10, shadow = False)
plt.title('Number of Room Types', fontsize= 20)
plt.show()

# %%
airbnb['host_name'].value_counts().head(10)
# Out:
# Mark               6
# Lulú               3
# Lisel              3
# Laurine            3
# Wayne              3
# Jessica            3
# Sara               3
# Ssameer Or Trip    3
# Bruce              3
# Laurie             3
# Name: host_name, dtype: int64

# %%
## Histogram of different host name

host_counts = airbnb['host_name'].value_counts()
top_hosts = host_counts.head(10)

# Create the countplot using only the top 5 hosts
plt.figure(figsize = (20, 8))
sns.countplot(y='host_name', data= airbnb[airbnb['host_name'].isin(top_hosts.index)], color= 'blue')

# Set the axis labels and title
plt.xlabel('Host Name', fontsize= 16)
plt.ylabel('Count', fontsize= 16)
plt.title('Number of Top 5 Host Names', fontsize= 25)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.show()

# %% [markdown]
# Relationship between price and neighbourhood group using Treemap

# %%
## Let’s check that relationship between price and Neighbourhood Group with a Treemap
#Importing required library for the map
import squarify

grouped = airbnb.groupby('neighbourhood_group')['price'].sum()

plt.figure(figsize=(10, 6))
colors = plt.cm.Dark2(range(10))
squarify.plot(sizes=grouped.values, label=grouped.index, alpha=0.7, color=colors)
plt.axis('off')
plt.title('Treemap of Sum of Prices by Neighborhoods Group', fontsize= 20)
plt.show()

# %% [markdown]
# # Scatterplot of latitude and longitude in relation with price

# %%
# Create a scatter plot of latitude and longitude with the color map based on the price column

plt.figure(figsize=(15, 5))
plt.scatter(airbnb['longitude'], airbnb['latitude'], c=airbnb['price'], cmap='viridis', alpha=0.9)

plt.xlabel('Longitude', fontsize= 15)
plt.ylabel('Latitude', fontsize= 15)
plt.title('Heatmap of Prices based on Location', fontsize= 20)

plt.colorbar()
plt.show()

# %%
sns.pairplot(data = airbnb, vars=["price","availability_365" , "minimum_nights"])
plt.show()

# %% [markdown]
# # Now Creating Visualization for hr-Dataset.

# %%
#Read the datasets
HR = pd.read_csv("HRDataset_v14.csv")

# %%
HR.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
# showing all columns in dataframe
print('No of Rows:', HR.shape[0])
print('No of Columns:', HR.shape[1])
pd.set_option('display.max_columns', None)
HR.head()
# Out:
# No of Rows: 311
# No of Columns: 36
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %%
## EmpID is a unique value in the dataset from where we can identify the number of duplicate data present in the dataset
## Find duplicates values in the 'EmpID' column
duplicates = HR.duplicated(subset= 'EmpID', keep= False)
HR[duplicates].sort_values('EmpID')
# Out:
# Empty DataFrame
# Columns: [Employee_Name, EmpID, MarriedID, MaritalStatusID, GenderID, EmpStatusID, DeptID, PerfScoreID, FromDiversityJobFairID, Salary, Termd, PositionID, Position, State, Zip, DOB, Sex, MaritalDesc, CitizenDesc, HispanicLatino, RaceDesc, DateofHire, DateofTermination, TermReason, EmploymentStatus, Department, ManagerName, ManagerID, RecruitmentSource, PerformanceScore, EngagementSurvey, EmpSatisfaction, SpecialProjectsCount, LastPerformanceReview_Date, DaysLateLast30, Absences]
# Index: []

# %%
HR.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
HR.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
# information about the dataset
HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
HR.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
HR.duplicated().sum()
# Out:
# 0

# %%
HR.columns.to_series().groupby(HR.dtypes).groups
# Out:
# {int64: ['EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID', 'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID', 'Salary', 'Termd', 'PositionID', 'Zip', 'EmpSatisfaction', 'SpecialProjectsCount', 'DaysLateLast30', 'Absences'], float64: ['ManagerID', 'EngagementSurvey'], object: ['Employee_Name', 'Position', 'State', 'DOB', 'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus', 'Department', 'ManagerName', 'RecruitmentSource', 'PerformanceScore', 'LastPerformanceReview_Date']}

# %%
missing_values = HR.isnull().sum().sort_values(ascending = False)
percentage_missing_values = (missing_values/len(HR))*100
print(pd.concat([missing_values, percentage_missing_values], axis=1, keys=['Missing Values', '%Missing data']))
# Out:
#                             Missing Values  %Missing data
# DateofTermination                      207      66.559486
# ManagerID                                8       2.572347
# EmpID                                    0       0.000000
# RaceDesc                                 0       0.000000
# DateofHire                               0       0.000000
# TermReason                               0       0.000000
# EmploymentStatus                         0       0.000000
# Department                               0       0.000000
# ManagerName                              0       0.000000
# Employee_Name                            0       0.000000
# RecruitmentSource                        0       0.000000
# PerformanceScore                         0       0.000000
# EngagementSurvey                         0       0.000000
# EmpSatisfaction                          0       0.000000
# SpecialProjectsCount                     0       0.000000
# ...

# %%
plt.figure(figsize=(28,10))
sns.heatmap(HR.describe(), linewidths =0.1, fmt='0.1f', annot = True, cmap='PiYG')
# Out:
# <Axes: >

# %%
HR.describe().T.round(3)
# Out:
#                         count       mean        std       min       25%  \
# EmpID                   311.0  10156.000     89.922  10001.00  10078.50
# MarriedID               311.0      0.399      0.490      0.00      0.00
# MaritalStatusID         311.0      0.810      0.943      0.00      0.00
# GenderID                311.0      0.434      0.496      0.00      0.00
# EmpStatusID             311.0      2.392      1.794      1.00      1.00
# DeptID                  311.0      4.611      1.083      1.00      5.00
# PerfScoreID             311.0      2.977      0.587      1.00      3.00
# FromDiversityJobFairID  311.0      0.093      0.291      0.00      0.00
# Salary                  311.0  69020.685  25156.637  45046.00  55501.50
# Termd                   311.0      0.334      0.473      0.00      0.00
# PositionID              311.0     16.846      6.223      1.00     18.00
# Zip                     311.0   6555.482  16908.397   1013.00   1901.50
# ...

# %%
HR['MarriedID'].value_counts()
# Out:
# 0    187
# 1    124
# Name: MarriedID, dtype: int64

# %%
labels = 1, 0
fig, ax = plt.subplots()
ax.pie(HR['MarriedID'].value_counts(),labels=labels,radius=2, autopct='%2.2f%%', explode=[0.1,0.2], shadow=True)
plt.show()

# %%
labels = 1, 0
fig, ax = plt.subplots()
ax.pie(HR['Sex'].value_counts(),labels=labels,radius=2, autopct='%2.2f%%', explode=[0.1,0.2], shadow=True)
plt.show()

# %%
Category=['Termd', 'Sex','MaritalDesc','CitizenDesc','RaceDesc','HispanicLatino']
for i in Category:
    print(i)
    print(HR[i].value_counts())
    print("="*100)
# Out:
# Termd
# 0    207
# 1    104
# Name: Termd, dtype: int64
# ...
# Sex
# F     176
# M     135
# Name: Sex, dtype: int64
# ...
# MaritalDesc
# Single       137
# Married      124
# Divorced      30
# Separated     12
# Widowed        8
# Name: MaritalDesc, dtype: int64
# ...
# CitizenDesc
# US Citizen             295
# Eligible NonCitizen     12
# Non-Citizen              4
# Name: CitizenDesc, dtype: int64
# ...
# RaceDesc
# White                               187
# Black or African American            80
# Asian                                29
# Two or more races                    11
# American Indian or Alaska Native      3
# Hispanic                              1
# Name: RaceDesc, dtype: int64
# ...
# HispanicLatino
# No     282
# Yes     27
# no       1
# yes      1
# Name: HispanicLatino, dtype: int64
# ...

# %%
HR['PerformanceScore'].unique()
# Out:
# array(['Exceeds', 'Fully Meets', 'Needs Improvement', 'PIP'], dtype=object)

# %%
HR['DateofTermination'].value_counts()
# Out:
# 8/19/2018    2
# 9/24/2012    2
# 5/17/2016    2
# 9/7/2015     2
# 4/4/2014     2
#             ..
# 1/11/2014    1
# 5/30/2011    1
# 3/15/2015    1
# 6/25/2015    1
# 9/29/2015    1
# Name: DateofTermination, Length: 96, dtype: int64

# %%
HR['DateofTermination'].isnull().sum()
# Out:
# 207

# %%
HR['DateofTermination'].fillna(' ', inplace=True)

# %%
HR['DateofTermination'].isnull().sum()
# Out:
# 0

# %%
HR.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %%
HR.corr
# Out:
# <bound method DataFrame.corr of                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
plt.figure(figsize = (20, 7))
sns.set_style('dark')

sns.distplot(HR['Salary'], bins= 25, color='#16213E')
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2488\3014256344.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(HR['Salary'], bins= 25, color='#16213E')

# %%
upper_triangle = np.triu(HR.corr())
plt.figure(figsize=(25,15))
sns.heatmap(HR.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f',
           annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2488\2493302729.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   upper_triangle = np.triu(HR.corr())
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2488\2493302729.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(HR.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f',

# %%
from imblearn.over_sampling import SMOTE

# %%
gender_label = HR['Sex'].value_counts().index
gender_count = HR['Sex'].value_counts()
explode = [0, 0.05]
color = ['#D14D72','#917FB3']

plt.figure(figsize = (7, 7))
plt.pie(gender_count, labels = gender_label, explode = explode, 
        colors= color, autopct='%1.0f%%', shadow = True)
plt.title('Distribution of Gender', fontsize= 20)

# Define the new labels
new_labels = ['Female', 'Male']
plt.legend(new_labels)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.show()

# %%
# Group the data by sex and marital status and count the number of occurrences
grouped = HR.groupby(['Sex', 'MaritalDesc']).size().reset_index(name='Count')

# Create the grouped bar chart
plt.figure(figsize = (20, 7))
sns.set_style('darkgrid')
sns.barplot(x='Sex', y='Count', hue='MaritalDesc', data=grouped)

plt.title('Marital Status by Gender', fontsize= 20)
plt.xlabel('Gender', fontsize= 16)
plt.ylabel('Count', fontsize= 16)
plt.xticks(fontsize= 14)
plt.yticks(fontsize= 14)
plt.show()

# %%
avg_salary_dpt = HR.groupby('Department')['Salary'].mean()
avg_salary_dpt
# Out:
# Department
# Admin Offices            71791.888889
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Production               59953.545455
# Sales                    69061.258065
# Software Engineering     94989.454545
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
sns.barplot(x = avg_salary_dpt.values, y = avg_salary_dpt.index, color= '#D14D72', orient= 'horizontal')

# Set the axis labels and title
plt.xlabel('Salary', fontsize= 16)
plt.ylabel('Position', fontsize= 16)
plt.title('Relationship between Average Salary and Department', fontsize= 20)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.show()

# %%
HR.plot.scatter(x="Salary", y="PositionID")
plt.show()

# %%
sns.pairplot(data=HR, vars=["Salary", "Sex", "State"])
plt.show()

# %%
msno.bar(HR)
plt.show()

# %%
HR['ManagerID'].isnull().sum()
# Out:
# 8

# %%
HR['ManagerID'].fillna('_', inplace=True)

# %%
HR['ManagerID'].isnull().sum()
# Out:
# 0

# %%
HR.to_csv('HRdataset_clean.csv')

# %% [markdown]
# # End of Assignment

# %% [markdown]
# Thank You
